# %% [markdown]
# # Berechnung der kritischen Konzentration c

# %%
# Für Kritische Konzentration
# Messung bei 60min - Expoentiell
data_3 = {
    "Konzentration": [1, 2.5, 4, 5],
    "t_B": [1.48, 4.98, 9.01, 29.1],
    "winkel_deg": [45, 45, 60, 75],
    "strecke_cm": [7, 7, 1, 1]
}

df3 = pd.DataFrame(data_3)

data_4 = {
    "Konzentration": [1, 2.5, 4, 5],
    "t_B": [1.26, 4.71, 11.68, 29.45],
    "winkel_deg": [45, 45, 60, 75],
    "strecke_cm": [7, 7, 1, 1]
}

df4 = pd.DataFrame(data_4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 10
#       1 # Für Kritische Konzentration
#       2 # Messung bei 60min - Expoentiell
#       3 data_3 = {
#       4     "Konzentration": [1, 2.5, 4, 5],
#       5     "t_B": [1.48, 4.98, 9.01, 29.1],
#       6     "winkel_deg": [45, 45, 60, 75],
#       7     "strecke_cm": [7, 7, 1, 1]
#       8 }
# ---> 10 df3 = pd.DataFrame(data_3)
#      12 data_4 = {
#      13     "Konzentration": [1, 2.5, 4, 5],
#      14     "t_B": [1.26, 4.71, 11.68, 29.45],
#      15     "winkel_deg": [45, 45, 60, 75],
#      16     "strecke_cm": [7, 7, 1, 1]
#      17 }
#      19 df4 = pd.DataFrame(data_4)
#
# NameError: name 'pd' is not defined
